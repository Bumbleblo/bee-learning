# %%
import pandas as pd 

data = pd.read_csv('minutely_measurements.csv')
# Out:
# /home/felipe/labs/mlflow/env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3050: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.describe()
# Out:
#         transductor  frequency+AF8-a  voltage+AF8-a  voltage+AF8-b  \
# count  8.312100e+04     83121.000000   83121.000000   83121.000000
# mean   8.930108e+07        59.935139     220.023483     230.190763
# std    4.810253e-01         0.985612       2.220028    1531.558186
# min    8.930108e+07         1.000000      50.000000     189.505569
# 25%    8.930108e+07        60.000000     218.638519     218.238037
# 50%    8.930108e+07        60.000000     220.022430     219.529861
# 75%    8.930108e+07        60.000000     221.381638     220.844238
# max    8.930108e+07        74.712776     229.320908  222125.000000
#
#        voltage+AF8-c  current+AF8-a  current+AF8-b  current+AF8-c  \
# count   83121.000000   83121.000000   83121.000000   83121.000000
# mean      239.931559       1.016275       1.110518       2.129035
# std      2161.044462       1.486463       1.351229       2.213506
# min       190.920013       0.016752       0.039011       0.099765
# ...

# %%
data.p
